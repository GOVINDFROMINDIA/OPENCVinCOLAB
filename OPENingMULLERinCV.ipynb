# %% [markdown]
# <a href="https://colab.research.google.com/github/GOVINDFROMINDIA/OPENCVinCOLAB/blob/main/OPENingMULLERinCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
img=cv2.imread('/content/MULLER.png',0)
cv2_imshow(img)
print(img.shape)
# Out:
# <PIL.Image.Image image mode=L size=1440x900 at 0x7FEE962C8190>
# (900, 1440)
